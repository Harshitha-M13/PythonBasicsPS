# %%
from datasets import load_dataset

df = load_dataset("lukebarousse/data_jobs")["train"].to_pandas()

# %%
df[df["salary_hour_avg"].notna()]           # Before droping Null values
# Out:
#              job_title_short  \
# 43      Senior Data Engineer
# 51      Senior Data Engineer
# 253            Data Engineer
# 294             Data Analyst
# 340             Data Analyst
# ...                      ...
# 784068         Data Engineer
# 784267  Senior Data Engineer
# 785111  Senior Data Engineer
# 785476        Data Scientist
# 785492        Data Scientist
#
#                                                 job_title        job_location  \
# 43      Sr SQL Database Engineer with Data Warehouse /...                 NaN
# 51                                   Senior Data Engineer            Anywhere
# 253                                         Data Engineer            Anywhere
# 294                                 Business/Data Analyst        Hartford, CT
# 340     23-00059 BI Data Analysts + Media experience -...          California
# ...                                                   ...                 ...
# ...

# %%
# after droping Null values of salary_year_avg column

df[df["salary_hour_avg"].notna()]
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
import pandas as pd

# %%
df.dropna(subset="salary_year_avg", inplace=True)


df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  str
#  1   job_title              22003 non-null  str
#  2   job_location           21723 non-null  str
#  3   job_via                22003 non-null  str
#  4   job_schedule_type      21987 non-null  str
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  str
#  7   job_posted_date        22003 non-null  datetime64[us]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  str
#  11  salary_rate            22003 non-null  str
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
#  14  company_name           22003 non-null  str
# ...

# %%
df["job_title_short"].value_counts()

# or

df.groupby("job_title_short")["salary_year_avg"].count()
# Out:
# job_title_short
# Business Analyst              610
# Cloud Engineer                 65
# Data Analyst                 5451
# Data Engineer                4500
# Data Scientist               5922
# Machine Learning Engineer     576
# Senior Data Analyst          1131
# Senior Data Engineer         1591
# Senior Data Scientist        1690
# Software Engineer             467
# Name: salary_year_avg, dtype: int64

# %%
df.groupby("job_title_short")

# %%
df.groupby("job_title_short")["salary_year_avg"]

# %%
df.groupby("job_title_short")["salary_year_avg"].sum()
# Out:
# job_title_short
# Business Analyst             5.556039e+07
# Cloud Engineer               7.232450e+06
# Data Analyst                 5.115322e+08
# Data Engineer                5.855652e+08
# Data Scientist               8.053259e+08
# Machine Learning Engineer    7.302201e+07
# Senior Data Analyst          1.288338e+08
# Senior Data Engineer         2.320324e+08
# Senior Data Scientist        2.606086e+08
# Software Engineer            5.295489e+07
# Name: salary_year_avg, dtype: float64

# %%
df.groupby("job_title_short")["salary_year_avg"].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby("job_title_short")["salary_year_avg"].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df[(df["job_title_short"] == "Data Engineer") & (df["salary_year_avg"] == 15000)]       # Checking and extracting
# Out:
#        job_title_short               job_title job_location       job_via  \
# 665729   Data Engineer  Data Engineer - Hadoop       Brazil  via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 665729         Full-time               False          Brazil
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 665729  2023-12-09 10:05:30                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 665729      Brazil        year          15000.0              NaN
#
#            company_name                                         job_skills  \
# 665729  Net2Source Inc.  ['java', 'python', 'oracle', 'aws', 'hadoop', ...
#
#                                           job_type_skills
# 665729  {'cloud': ['oracle', 'aws'], 'libraries': ['ha...

# %%
df.groupby(["job_title_short", "job_country"])["salary_year_avg"].sum()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan         0.0
#                    Albania             0.0
#                    Algeria             0.0
#                    Angola              0.0
#                    Argentina      142200.0
#                                     ...
# Software Engineer  Venezuela           0.0
#                    Vietnam        107200.0
#                    Yemen               0.0
#                    Zambia              0.0
#                    Zimbabwe            0.0
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df[df["job_country"] == "Albania"]          # before droping the nan values
# Out:
#               job_title_short                               job_title  \
# 3095            Data Engineer                    Oracle Data Engineer
# 5194    Senior Data Scientist  Senior Data Scientist (f/m/x), Albania
# 5284            Data Engineer                           Data Engineer
# 9047         Business Analyst           Business Intelligence Analyst
# 9897            Data Engineer                           Data Engineer
# ...                       ...                                     ...
# 679738  Senior Data Scientist  Senior Data Scientist (f/m/x), Albania
# 686360      Software Engineer      Back-End/Laravel Software Engineer
# 721510          Data Engineer                       Sn. Data Engineer
# 724547      Software Engineer                      Developer Advocate
# 736852          Data Engineer        Data Network Operations Engineer
#
#            job_location               job_via job_schedule_type  \
# ...

# %%
df[(df["job_country"] == "Albania") & (df["job_title_short"] == "Business Analyst")]            # Confirmation
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
df.groupby(["job_title_short", "job_country"])["salary_year_avg"].sum()     # as we can see here there is no "Albania", because there is no value other than "Nan" there for "salary_year_avg" column: "Pandas will ignore Nan values and then ) is returned since no values remains"
# Out:
# job_title_short    job_country
# Business Analyst   Argentina               1.422000e+05
#                    Australia               2.630000e+05
#                    Bangladesh              1.650000e+04
#                    Belgium                 4.131000e+05
#                    Bulgaria                2.959500e+05
#                                                ...
# Software Engineer  Ukraine                 5.400000e+04
#                    United Arab Emirates    7.920000e+04
#                    United Kingdom          5.164000e+05
#                    United States           2.166049e+07
#                    Vietnam                 1.072000e+05
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].mean()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst              91082.612833              NaN
# Cloud Engineer               111268.453846              NaN
# Data Analyst                  93841.907854              NaN
# Data Engineer                130125.604250              NaN
# Data Scientist               135988.837171              NaN
# Machine Learning Engineer    126774.315972              NaN
# Senior Data Analyst          113911.363665              NaN
# Senior Data Engineer         145840.611624              NaN
# Senior Data Scientist        154206.292996              NaN
# Software Engineer            113393.760054              NaN

# %%
df.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0              NaN
# Cloud Engineer                     90000.0              NaN
# Data Analyst                       90000.0              NaN
# Data Engineer                     125000.0              NaN
# Data Scientist                    127500.0              NaN
# Machine Learning Engineer         106415.0              NaN
# Senior Data Analyst               111175.0              NaN
# Senior Data Engineer              147500.0              NaN
# Senior Data Scientist             155500.0              NaN
# Software Engineer                  99150.0              NaN

# %%
df.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].count()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                       610                0
# Cloud Engineer                          65                0
# Data Analyst                          5451                0
# Data Engineer                         4500                0
# Data Scientist                        5922                0
# Machine Learning Engineer              576                0
# Senior Data Analyst                   1131                0
# Senior Data Engineer                  1591                0
# Senior Data Scientist                 1690                0
# Software Engineer                      467                0

# %%
df[df["salary_hour_avg"].notna()]       # proof
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].sum()
# Out:
#                                         salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Argentina                1.422000e+05              0.0
#                   Australia                2.630000e+05              0.0
#                   Bangladesh               1.650000e+04              0.0
#                   Belgium                  4.131000e+05              0.0
#                   Bulgaria                 2.959500e+05              0.0
# ...                                                 ...              ...
# Software Engineer Ukraine                  5.400000e+04              0.0
#                   United Arab Emirates     7.920000e+04              0.0
#                   United Kingdom           5.164000e+05              0.0
#                   United States            2.166049e+07              0.0
#                   Vietnam                  1.072000e+05              0.0
#
# [598 rows x 2 columns]

# %%
# After removeing - df.dropna(subset="salary_year_avg", inplace=True) and replacing it with - df.dropna(subset="salary_year_avg") or reloading the dataframe

df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].sum()
# Out:
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              0.0              0.0
#                   Albania                  0.0              0.0
#                   Algeria                  0.0              0.0
#                   Angola                   0.0              0.0
#                   Argentina           142200.0              0.0
# ...                                        ...              ...
# Software Engineer Venezuela                0.0              0.0
#                   Vietnam             107200.0              0.0
#                   Yemen                    0.0              0.0
#                   Zambia                   0.0              0.0
#                   Zimbabwe                 0.0              0.0
#
# [1387 rows x 2 columns]

# %%
df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].mean()
# Out:
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              NaN              NaN
#                   Albania                  NaN              NaN
#                   Algeria                  NaN              NaN
#                   Angola                   NaN              NaN
#                   Argentina            71100.0              NaN
# ...                                        ...              ...
# Software Engineer Venezuela                NaN              NaN
#                   Vietnam              53600.0              NaN
#                   Yemen                    NaN              NaN
#                   Zambia                   NaN              NaN
#                   Zimbabwe                 NaN              NaN
#
# [1387 rows x 2 columns]

# %%
df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].median()
# Out:
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan              NaN              NaN
#                   Albania                  NaN              NaN
#                   Algeria                  NaN              NaN
#                   Angola                   NaN              NaN
#                   Argentina            71100.0              NaN
# ...                                        ...              ...
# Software Engineer Venezuela                NaN              NaN
#                   Vietnam              53600.0              NaN
#                   Yemen                    NaN              NaN
#                   Zambia                   NaN              NaN
#                   Zimbabwe                 NaN              NaN
#
# [1387 rows x 2 columns]

# %%
df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].count()
# Out:
#                                salary_year_avg  salary_hour_avg
# job_title_short   job_country
# Business Analyst  Afghanistan                0                0
#                   Albania                    0                0
#                   Algeria                    0                0
#                   Angola                     0                0
#                   Argentina                  2                0
# ...                                        ...              ...
# Software Engineer Venezuela                  0                0
#                   Vietnam                    2                0
#                   Yemen                      0                0
#                   Zambia                     0                0
#                   Zimbabwe                   0                0
#
# [1387 rows x 2 columns]

# %%
# If we want to perform all the methods together
df.groupby(["job_title_short", "job_country"])[["salary_year_avg"]].agg(["min", "max", "mean", "median", "count"])
# Out:
#                               salary_year_avg
#                                           min      max     mean   median count
# job_title_short   job_country
# Business Analyst  Afghanistan             NaN      NaN      NaN      NaN     0
#                   Albania                 NaN      NaN      NaN      NaN     0
#                   Algeria                 NaN      NaN      NaN      NaN     0
#                   Angola                  NaN      NaN      NaN      NaN     0
#                   Argentina           63000.0  79200.0  71100.0  71100.0     2
# ...                                       ...      ...      ...      ...   ...
# Software Engineer Venezuela               NaN      NaN      NaN      NaN     0
#                   Vietnam             28000.0  79200.0  53600.0  53600.0     2
#                   Yemen                   NaN      NaN      NaN      NaN     0
#                   Zambia                  NaN      NaN      NaN      NaN     0
# ...

# %%
df.groupby(["job_title_short", "job_country"])[["salary_year_avg", "salary_hour_avg"]].agg(["min", "max", "mean", "median", "count"])
# Out:
#                               salary_year_avg                             \
#                                           min      max     mean   median
# job_title_short   job_country
# Business Analyst  Afghanistan             NaN      NaN      NaN      NaN
#                   Albania                 NaN      NaN      NaN      NaN
#                   Algeria                 NaN      NaN      NaN      NaN
#                   Angola                  NaN      NaN      NaN      NaN
#                   Argentina           63000.0  79200.0  71100.0  71100.0
# ...                                       ...      ...      ...      ...
# Software Engineer Venezuela               NaN      NaN      NaN      NaN
#                   Vietnam             28000.0  79200.0  53600.0  53600.0
#                   Yemen                   NaN      NaN      NaN      NaN
#                   Zambia                  NaN      NaN      NaN      NaN
# ...

# %%
df["job_country"]
# Out:
# 0         United States
# 1                Mexico
# 2               Germany
# 3         United States
# 4                 Sudan
#               ...
# 785736        Singapore
# 785737          Germany
# 785738         Malaysia
# 785739            Sudan
# 785740            India
# Name: job_country, Length: 785741, dtype: str

# %%
df["job_country"].unique()
# Out:
# <ArrowStringArray>
# [           'United States',                   'Mexico',
#                   'Germany',                    'Sudan',
#                   'Romania',                  'Denmark',
#               'Switzerland',                   'France',
#                    'Brazil',           'United Kingdom',
#  ...
#  'Northern Mariana Islands',                   'Angola',
#                   'Somalia',         'Papua New Guinea',
#                    'Gambia',                 'Djibouti',
#                      'Laos',                  'Curaçao',
#                  'Maldives',                   'Bhutan']
# Length: 161, dtype: str

# %%
df["job_country"].value_counts()
# Out:
# job_country
# United States               206292
# India                        51088
# United Kingdom               40375
# France                       39922
# Germany                      27694
#                              ...
# Northern Mariana Islands         4
# Lesotho                          3
# Mauritania                       3
# Bhutan                           3
# Maldives                         2
# Name: count, Length: 160, dtype: int64

# %%
# top 20

df["job_country"].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df["job_country"].isin(["Brazil"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
df["job_country"].isin(["Brazil"]).any()
# Out:
# np.True_

# %%
df[df["job_country"] == "Brazil"]
# Out:
#                   job_title_short  \
# 14                  Data Engineer
# 55                 Data Scientist
# 84                 Data Scientist
# 169                  Data Analyst
# 282                 Data Engineer
# ...                           ...
# 784760          Software Engineer
# 784968           Business Analyst
# 785223       Senior Data Engineer
# 785342  Machine Learning Engineer
# 785556              Data Engineer
#
#                                                 job_title  \
# 14                                          Data Engineer
# 55                                         Data Scientist
# 84                                           Data Science
# 169                                       Digital Analyst
# 282                                         Data Engineer
# ...                                                   ...
# 784760                                        MS Engineer
# 784968               Communications and Reporting Analyst
# ...

# %%
df[df["job_country"] == "Brazil"].count()
# Out:
# job_title_short          7032
# job_title                7032
# job_location             7032
# job_via                  7032
# job_schedule_type        7015
# job_work_from_home       7032
# search_location          7032
# job_posted_date          7032
# job_no_degree_mention    7032
# job_health_insurance     7032
# job_country              7032
# salary_rate                68
# salary_year_avg            61
# salary_hour_avg             6
# company_name             7031
# job_skills               6190
# job_type_skills          6190
# dtype: int64

# %%
df["job_country"].isin(["India"]).any()
# Out:
# np.True_

# %%
df["job_country"].isin(["North Korea"]).any()
# Out:
# np.False_

# %%
uk_jobs = df[df["job_country"] == "United Kingdom"]

# %%
uk_jobs
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# ...

# %%
uk_jobs["job_title_short"].unique()
# Out:
# <ArrowStringArray>
# [            'Data Engineer',       'Senior Data Analyst',
#               'Data Analyst',            'Data Scientist',
#      'Senior Data Scientist',      'Senior Data Engineer',
#           'Business Analyst',         'Software Engineer',
#  'Machine Learning Engineer',            'Cloud Engineer']
# Length: 10, dtype: str

# %%
uk_jobs.count()             # Like Overview
# Out:
# job_title_short          40375
# job_title                40375
# job_location             40361
# job_via                  40375
# job_schedule_type        40046
# job_work_from_home       40375
# search_location          40375
# job_posted_date          40375
# job_no_degree_mention    40375
# job_health_insurance     40375
# job_country              40375
# salary_rate                290
# salary_year_avg            287
# salary_hour_avg              3
# company_name             40375
# job_skills               34126
# job_type_skills          34126
# dtype: int64

# %%
# More detailed information
uk_jobs.groupby("job_title_short").count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                   5             5        5
# Data Analyst                      72            72       72
# Data Engineer                     60            60       60
# Data Scientist                    75            75       75
# Machine Learning Engineer          7             7        7
# Senior Data Analyst                8             8        8
# Senior Data Engineer              24            24       24
# Senior Data Scientist             31            31       31
# Software Engineer                  5             5        5
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                           5                   5
# Data Analyst                              72                  72
# Data Engineer                             60                  60
# Data Scientist                            75                  75
# ...

# %%
uk_jobs.groupby("job_title_short")["job_title_short"].count()       # More detailed information on job_title_short only
# Out:
# job_title_short
# Business Analyst              5
# Data Analyst                 72
# Data Engineer                60
# Data Scientist               75
# Machine Learning Engineer     7
# Senior Data Analyst           8
# Senior Data Engineer         24
# Senior Data Scientist        31
# Software Engineer             5
# Name: job_title_short, dtype: int64

# %%
#or
uk_jobs["job_title_short"].value_counts()
# Out:
# job_title_short
# Data Scientist               75
# Data Analyst                 72
# Data Engineer                60
# Senior Data Scientist        31
# Senior Data Engineer         24
# Senior Data Analyst           8
# Machine Learning Engineer     7
# Software Engineer             5
# Business Analyst              5
# Name: count, dtype: int64

# %%
uk_jobs[uk_jobs["salary_hour_avg"].isnull()]
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# ...

# %%
uk_jobs = uk_jobs[uk_jobs["salary_year_avg"].notna()]

# %%
uk_jobs
# Out:
#               job_title_short                                       job_title  \
# 1107           Data Scientist         Data Scientist, Customer AI Engineering
# 2602             Data Analyst                            Admin & Data Analyst
# 9778      Senior Data Analyst  Workday HCM Senior Data Analyst (18 month FTC)
# 9903     Senior Data Engineer        Senior Satellite Analytics Data Engineer
# 13764          Data Scientist                    Programmatic Data Specialist
# ...                       ...                                             ...
# 781461         Data Scientist                                  Data Scientist
# 783284  Senior Data Scientist                           Senior Data Scientist
# 783436         Data Scientist                                 Insight Analyst
# 783598          Data Engineer                                   Data Engineer
# 783748          Data Engineer                                   Data Engineer
#
# ...

# %%
uk_jobs[uk_jobs["salary_year_avg"].isnull()]
# Out:
# Empty DataFrame
# Columns: [job_title_short, job_title, job_location, job_via, job_schedule_type, job_work_from_home, search_location, job_posted_date, job_no_degree_mention, job_health_insurance, job_country, salary_rate, salary_year_avg, salary_hour_avg, company_name, job_skills, job_type_skills]
# Index: []

# %%
uk_jobs.groupby("job_title_short")["salary_year_avg"].count()       # Best Practice
# Out:
# job_title_short
# Business Analyst              5
# Data Analyst                 72
# Data Engineer                60
# Data Scientist               75
# Machine Learning Engineer     7
# Senior Data Analyst           8
# Senior Data Engineer         24
# Senior Data Scientist        31
# Software Engineer             5
# Name: salary_year_avg, dtype: int64

# %%
uk_jobs.groupby("job_title_short").count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                   5             5        5
# Data Analyst                      72            72       72
# Data Engineer                     60            60       60
# Data Scientist                    75            75       75
# Machine Learning Engineer          7             7        7
# Senior Data Analyst                8             8        8
# Senior Data Engineer              24            24       24
# Senior Data Scientist             31            31       31
# Software Engineer                  5             5        5
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                           5                   5
# Data Analyst                              72                  72
# Data Engineer                             60                  60
# Data Scientist                            75                  75
# ...

# %%
uk_jobs.groupby("job_title_short").min()
# Out:
#                                                                    job_title  \
# job_title_short
# Business Analyst           Analyste en intelligence d'affaires (hybride)/...
# Data Analyst                                            Admin & Data Analyst
# Data Engineer                                              AWS Data Engineer
# Data Scientist                                            Analytics Engineer
# Machine Learning Engineer                    Deep Learning Research Engineer
# Senior Data Analyst                         Data Operations Account Director
# Senior Data Engineer                                Senior Big Data Engineer
# Senior Data Scientist                 Data Scientist / Senior Data Scientist
# Software Engineer             Lead/Senior Software Engineer (Data Pipelines)
#
#                             job_location            job_via job_schedule_type  \
# job_title_short
# Business Analyst              London, UK    via Ai-Jobs.net         Full-time
# ...

# %%
uk_jobs.groupby("job_title_short")["salary_year_avg"].min()       # Best Practice
# Out:
# job_title_short
# Business Analyst             30000.0
# Data Analyst                 30000.0
# Data Engineer                35000.0
# Data Scientist               33488.5
# Machine Learning Engineer    85205.0
# Senior Data Analyst          79200.0
# Senior Data Engineer         45000.0
# Senior Data Scientist        72500.0
# Software Engineer            89100.0
# Name: salary_year_avg, dtype: float64

# %%
uk_jobs.groupby("job_title_short")[["salary_year_avg"]].min()       # Best Practice
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   30000.0
# Data Analyst                       30000.0
# Data Engineer                      35000.0
# Data Scientist                     33488.5
# Machine Learning Engineer          85205.0
# Senior Data Analyst                79200.0
# Senior Data Engineer               45000.0
# Senior Data Scientist              72500.0
# Software Engineer                  89100.0

# %%
uk_jobs.groupby(["job_title_short"])["salary_year_avg"].min()       # Best Practice
# Out:
# job_title_short
# Business Analyst             30000.0
# Data Analyst                 30000.0
# Data Engineer                35000.0
# Data Scientist               33488.5
# Machine Learning Engineer    85205.0
# Senior Data Analyst          79200.0
# Senior Data Engineer         45000.0
# Senior Data Scientist        72500.0
# Software Engineer            89100.0
# Name: salary_year_avg, dtype: float64

# %%
uk_jobs.groupby("job_title_short")["salary_year_avg"].agg(["min", "max", "count", "mean", "median"])
# Out:
#                                min       max  count           mean    median
# job_title_short
# Business Analyst           30000.0   73500.0      5   49560.000000   56700.0
# Data Analyst               30000.0  180000.0     72   89410.916667   87750.0
# Data Engineer              35000.0  249000.0     60  115622.200000  110000.0
# Data Scientist             33488.5  205000.0     75  110250.933333  105300.0
# Machine Learning Engineer  85205.0  200000.0      7  139564.428571  149653.0
# Senior Data Analyst        79200.0  118140.0      8  107314.375000  111175.0
# Senior Data Engineer       45000.0  171620.0     24  137550.020833  147500.0
# Senior Data Scientist      72500.0  170575.0     31  129399.225806  157500.0
# Software Engineer          89100.0  160000.0      5  103280.000000   89100.0

# %%
uk_jobs.groupby("job_title_short")["salary_year_avg"].agg(["min", "max", "count", "mean", "median"]).sort_values(by="median")
# Out:
#                                min       max  count           mean    median
# job_title_short
# Business Analyst           30000.0   73500.0      5   49560.000000   56700.0
# Data Analyst               30000.0  180000.0     72   89410.916667   87750.0
# Software Engineer          89100.0  160000.0      5  103280.000000   89100.0
# Data Scientist             33488.5  205000.0     75  110250.933333  105300.0
# Data Engineer              35000.0  249000.0     60  115622.200000  110000.0
# Senior Data Analyst        79200.0  118140.0      8  107314.375000  111175.0
# Senior Data Engineer       45000.0  171620.0     24  137550.020833  147500.0
# Machine Learning Engineer  85205.0  200000.0      7  139564.428571  149653.0
# Senior Data Scientist      72500.0  170575.0     31  129399.225806  157500.0

# %%
uk_jobs.groupby("job_title_short")["salary_year_avg"].agg(["min", "max", "count", "mean", "median"]).sort_values(by="median", ascending=False)
# Out:
#                                min       max  count           mean    median
# job_title_short
# Senior Data Scientist      72500.0  170575.0     31  129399.225806  157500.0
# Machine Learning Engineer  85205.0  200000.0      7  139564.428571  149653.0
# Senior Data Engineer       45000.0  171620.0     24  137550.020833  147500.0
# Senior Data Analyst        79200.0  118140.0      8  107314.375000  111175.0
# Data Engineer              35000.0  249000.0     60  115622.200000  110000.0
# Data Scientist             33488.5  205000.0     75  110250.933333  105300.0
# Software Engineer          89100.0  160000.0      5  103280.000000   89100.0
# Data Analyst               30000.0  180000.0     72   89410.916667   87750.0
# Business Analyst           30000.0   73500.0      5   49560.000000   56700.0

# %%
uk_jobs.groupby("job_title_short")[["salary_year_avg"]].agg(["min", "max", "count", "mean", "median"]).sort_values(by="median")         # Error - [["salary_year_avg"]] is not Series it is an DataFrame, pandas check for column name - "median" which it will not find and throws an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 uk_jobs.groupby("job_title_short")[["salary_year_avg"]].agg(["min", "max", "count", "mean", "median"]).sort_values(by="median")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# ...

# %%
uk_jobs.groupby("job_title_short")[["salary_year_avg"]].agg(["min", "max", "count", "mean", "median"]).sort_values(by="job_title_short")   # Since the column  name "job_title_short" exists no Error!
# Out:
#                           salary_year_avg                                 \
#                                       min       max count           mean
# job_title_short
# Business Analyst                  30000.0   73500.0     5   49560.000000
# Data Analyst                      30000.0  180000.0    72   89410.916667
# Data Engineer                     35000.0  249000.0    60  115622.200000
# Data Scientist                    33488.5  205000.0    75  110250.933333
# Machine Learning Engineer         85205.0  200000.0     7  139564.428571
# Senior Data Analyst               79200.0  118140.0     8  107314.375000
# Senior Data Engineer              45000.0  171620.0    24  137550.020833
# Senior Data Scientist             72500.0  170575.0    31  129399.225806
# Software Engineer                 89100.0  160000.0     5  103280.000000
#
#
#                              median
# job_title_short
# Business Analyst            56700.0
# Data Analyst                87750.0
# ...

# %%
uk_jobs["job_title_short"].sort_values()
# Out:
# 166572     Business Analyst
# 387745     Business Analyst
# 405777     Business Analyst
# 431877     Business Analyst
# 508380     Business Analyst
#                 ...
# 130904    Software Engineer
# 681531    Software Engineer
# 694137    Software Engineer
# 731081    Software Engineer
# 779691    Software Engineer
# Name: job_title_short, Length: 287, dtype: str

# %%
uk_jobs[["job_title_short"]].sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 uk_jobs[["job_title_short"]].sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
uk_jobs[["job_title_short"]].sort_values(by="job_title_short")
# Out:
#           job_title_short
# 166572   Business Analyst
# 387745   Business Analyst
# 405777   Business Analyst
# 431877   Business Analyst
# 508380   Business Analyst
# ...                   ...
# 130904  Software Engineer
# 681531  Software Engineer
# 694137  Software Engineer
# 731081  Software Engineer
# 779691  Software Engineer
#
# [287 rows x 1 columns]

# %%
uk_jobs.sort_values("job_title_short")
# Out:
#           job_title_short                                          job_title  \
# 166572   Business Analyst     Senior Director, Head of Business Intelligence
# 387745   Business Analyst                   Business Intelligence Specialist
# 405777   Business Analyst                      Business Intelligence Analyst
# 431877   Business Analyst  Analyste en intelligence d'affaires (hybride)/...
# 508380   Business Analyst      Senior Business Analyst - ESG - Data Products
# ...                   ...                                                ...
# 130904  Software Engineer     Lead/Senior Software Engineer (Data Pipelines)
# 681531  Software Engineer                     Software Engineer, Market Data
# 694137  Software Engineer  Senior Software Engineer, Data Processing & Wo...
# 731081  Software Engineer  MUFG 2024 UK Technology Analyst Programme: Arc...
# 779691  Software Engineer       Software Engineer (Machine Learning), London
#
# ...
