# %%
import module_1
import importlib

# %%
module_1.skills
# Out:
# ['Python', 'SQL', 'Tableau']

# %%
module_1.fav_skill("Python")
# Out:
# 'Python is our favorite!'

# %%
module_1.add(3, 6)      # Once the file(module_1) has been loaded in first-line[import module_1], after that if we code something in module_1(in our case - add() func) it would throw "Error"

'''
    After loading - import module_1
    We edited module_1
    module_2 doesn't re-read the file(module_1)
'''
# Because module_2 will not re-collect it(add() func - new func) from module_1
# Out:
# 9

# %%
module_1.sub(6, 3)
# Out:
# 3

# %%
importlib.reload(module_1)

module_1.mul(3, 3)
# Out:
# 9

# %%
importlib.reload(module_1)

module_1.calculate_salary(30_00_000)
# Out:
# 3300000.0000000005

# %%
from module_1 import calculate_salary

help(calculate_salary)
# Out:
# Help on function calculate_salary in module module_1:
#
# calculate_salary(base_salary, bonus_rate=0.1)
#     # New Function

# %%
# So, after using doc-string

importlib.reload(module_1)

help(calculate_salary)
# Out:
# Help on function calculate_salary in module module_1:
#
# calculate_salary(base_salary, bonus_rate=0.1)
#     Calculate the total salary based on the base salary and bonus rate
#
#     Args:
#         base_salary (float): The base salary.
#         bonus_rate (float): The bonus rate. Default is .1.
#
#     Returns:
#         total_salary (float): The total salary

# %%
from module_1 import * 
importlib.reload(module_1)


help(cal_bonus_rate)
# Out:
# Help on function cal_bonus_rate in module module_1:
#
# cal_bonus_rate(total_salary, base_salary)
#     Calculates bonus rate based on the total salary and base salary
#
#     Args:
#         total_salary (float): The total salary
#         Base_salary (float): The base salary
#
#     Returns:
#         bonus_rate (float): The bonus rate

# %%
from statistics import mean, median, mode # issue so we won't import all - i.e *

our_list = [1, 2, 3, 4, 5]

def mode(name):
    print("Welcome!", name)

# %%
mode("GowriShankar")
# Out:
# Welcome! GowriShankar

# %%
from statistics import mean, median, mode

our_list = [3, 4, 5, 1, 2, 6]   # arrange in ascending order and then calculate

mean(our_list)      # 3
median(our_list)    # > [1, 2, 3, 4, 5, 6] > (3 + 4) / 2
mode(our_list)      # 1st element if not frequent/ repeated
# Out:
# 3

# %%
help(mode)
# Out:
# Help on function mode in module statistics:
#
# mode(data)
#     Return the most common data point from discrete or nominal data.
#
#     ``mode`` assumes discrete data, and returns a single value. This is the
#     standard treatment of the mode as commonly taught in schools:
#
#         >>> mode([1, 1, 2, 3, 3, 3, 3, 4])
#         3
#
#     This also works with nominal (non-numeric) data:
#
#         >>> mode(["red", "blue", "blue", "red", "green", "red", "red"])
#         'red'
#
#     If there are multiple modes with same frequency, return the first one
#     encountered:
#
#         >>> mode(['red', 'red', 'green', 'blue', 'blue'])
#         'red'
#
#     If *data* is empty, ``mode``, raises StatisticsError.

# %%
help(median)
# Out:
# Help on function median in module statistics:
#
# median(data)
#     Return the median (middle value) of numeric data.
#
#     When the number of data points is odd, return the middle data point.
#     When the number of data points is even, the median is interpolated by
#     taking the average of the two middle values:
#
#     >>> median([1, 3, 5])
#     3
#     >>> median([1, 3, 5, 7])
#     4.0

# %%
help(mean)
