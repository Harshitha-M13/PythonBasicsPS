# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Datasets 
df = load_dataset("lukebarousse/data_jobs")["train"].to_pandas()

# Data cleanup
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %% [markdown]
# # Using .fillna()

# %%
median_salary_year = df["salary_year_avg"].median()

median_salary_year
# Out:
# np.float64(115000.0)

# %%
median_salary_hour = df["salary_hour_avg"].median()

median_salary_hour
# Out:
# np.float64(45.97999954223633)

# %%
df["salary_year_avg", "salary_hour_avg"].median()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: ('salary_year_avg', 'salary_hour_avg')
#
# ...

# %%
df[["salary_year_avg", "salary_hour_avg"]].median()
# Out:
# salary_year_avg    115000.00
# salary_hour_avg        45.98
# dtype: float64

# %%
df_fillna_with_median = df  # Is pointing to the same address in memory

# %%
id(df) == id(df_fillna_with_median)
# Out:
# True

# %%
df_fillna_with_median["salary_year_avg"].fillna(value=median_salary_year, inplace=True) # It cannot guarantee that this temporary Series is the original DataFrame's actual column. - that's why we get "ChainedAssignmentError"
# Out:
# /var/folders/sb/1g2bvg3j24d8rsnjkzpf_dqr0000gn/T/ipykernel_25754/4292562433.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
# ...

# %%
df_fillna_with_median.loc[:10, :]       # No replacement is done
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1           Data Analyst                                       Data Analyst
# 2          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4          Data Engineer                             Data Engineer- Sr Jobs
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7          Data Engineer                                      Data Engineer
# 8       Business Analyst           Technology & Operations Business Analyst
# 9         Data Scientist                                  Data Scientist II
# 10         Data Engineer               Erfahrene*r Data Engineer*in (m/w/d)
#
#                     job_location             job_via  \
# ...

# %%
# We can do this instead, because we are re-assigning it
df_fillna_with_median["salary_year_avg"] = df_fillna_with_median["salary_year_avg"].fillna(value=median_salary_year)

# %%
df.head(3)          # It has also effected in - the original DataFrame
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_fillna_with_median.head(3)       # observe "salary_year_avg" column
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
# Best Practice

import copy as cp

df_fillna_with_median = cp.deepcopy(df)

df_fillna_with_median.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_fillna_with_median["salary_year_avg"].fillna(value=median_salary_year, inplace=True)
# Out:
# /var/folders/sb/1g2bvg3j24d8rsnjkzpf_dqr0000gn/T/ipykernel_25754/1614382564.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_fillna_with_median["salary_year_avg"].fillna(value=median_salary_year, inplace=True)
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
# ...

# %%
df_fillna_with_median["salary_year_avg"] = df_fillna_with_median["salary_year_avg"].fillna(value=median_salary_year)

# %%
df.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_fillna_with_median.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_fillna_with_median["salary_hour_avg"] = df_fillna_with_median["salary_hour_avg"].fillna(value=median_salary_hour)

# %%
df_fillna_with_median.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
"""
df["search_location"]:

This is a Series containing many values:

0    Texas, United States
1    Mexico
2    Germany
3    United States
4    California, United States

What python is doing - Is the entire Series df["search_location"] inside the string "United States"? i.e - [all 785,741 values] in "United States"
..."""


df["search_location"] in "United States"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[316], line 16
#      12 What python is doing - Is the entire Series df["search_location"] inside the string "United States"? i.e - [all 785,741 values] in "United States"
#      13 ..."""
#      14
#      15
# ---> 16 df["search_location"] in "United States"
#
# TypeError: 'in <string>' requires string as left operand, not Series

# %%
"United States" in df["search_location"] # Python checks whether "United States" is in the Series index, not necessarily in the values. - EX: [0, 1, 2, 3, 4, ...]
# Out:
# False

# %%
0 in df["search_location"]      # Proof
# Out:
# True

# %%
# Best Practice 
"""
.str means:
* Apply a string operation to every value in this column.
* So instead of checking just one string, pandas will check every row.


NaN is not a string.
na=False : If the value is NaN, treat the result as False.
"""
df["search_location"].str.contains("United States", na=False)
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: search_location, Length: 785741, dtype: bool

# %%
"Data Science".contains("Data")  # It is not Pandas, it is str we will have to use - "Data" in "Data Science" for "normal String"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 "Data Science".contains("Data")  # It is not Pandas, it is str we will have to use - "Data" in "Data Science" for "normal String"
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
df["search_location"].str.contains("United States")
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: search_location, Length: 785741, dtype: bool

# %%
df[df["search_location"].str.contains("United States", na=False)]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# 11             Data Engineer
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 6                       Senior Data Engineer  - GCP Cloud
# 9                                       Data Scientist II
# 11                                          Data Engineer
# ...                                                   ...
# 785673                    Asset Management Data Scientist
# 785685                                       Data Analyst
# 785692               Data Scientist- Hybrid Work Location
# ...

# %%
df[df["search_location"].str.contains("United States", na=False)].count()
# Out:
# job_title_short          173868
# job_title                173868
# job_location             173169
# job_via                  173861
# job_schedule_type        172843
# job_work_from_home       173868
# search_location          173868
# job_posted_date          173868
# job_no_degree_mention    173868
# job_health_insurance     173868
# job_country              173868
# salary_rate               21699
# salary_year_avg          173868
# salary_hour_avg            8002
# company_name             173868
# job_skills               153306
# job_type_skills          153306
# dtype: int64

# %%
df[(df["job_title_short"] == "Data Analyst") & df["job_via"].str.contains("LinkedIn")]
# Out:
#        job_title_short                                          job_title  \
# 31        Data Analyst                           Stage - Data Analyst F/H
# 46        Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# 73        Data Analyst        Entry level / Systems Data Analyst (Remote)
# 93        Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 123       Data Analyst  Data Analytics work from home job/internship a...
# ...                ...                                                ...
# 785548    Data Analyst                                       Data Analyst
# 785566    Data Analyst    Data and Analytics Platforms and Infrastructure
# 785628    Data Analyst                                       Data Analyst
# 785691    Data Analyst                     Business Intelligence Engineer
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
#
#                                           job_location           job_via  \
# ...

# %% [markdown]
# # Drop Duplicates
#
# * drop_duplicates()

# %%
import copy as cp

df_unique = cp.deepcopy(df_fillna_with_median)

df_unique.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_unique
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
print(f"Number of rows in original dataFrame: {len(df_unique)}")
df_unique.drop_duplicates(inplace = True)
print(f"Number of rows after droping the duplicates: {len(df_unique)}")
print(f"Number of rows Delected: {len(df_fillna_with_median) - len(df_unique)}")
# Out:
# Number of rows in original dataFrame: 785741
# Number of rows after droping the duplicates: 785640
# Number of rows Delected: 101

# %%
# Not the best practice

df_unique = df_fillna_with_median

df_unique.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
print(f"Number of rows in original dataFrame: {len(df_unique)}")
df_unique.drop_duplicates(inplace = True)
print(f"Number of rows after droping the duplicates: {len(df_unique)}")
print(f"Number of rows Delected: {len(df_fillna_with_median) - len(df_unique)}")
# Out:
# Number of rows in original dataFrame: 785741
# Number of rows after droping the duplicates: 785640
# Number of rows Delected: 0

# %%
len(df_fillna_with_median) == len(df_unique)
# Out:
# True

# %%
df_unique.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_unique[(df_unique["job_title"] == "Data Analyst") & (df_unique["job_country"] == "Mexico")]
# Out:
#        job_title_short     job_title                          job_location  \
# 1         Data Analyst  Data Analyst          Guadalajara, Jalisco, Mexico
# 4216      Data Analyst  Data Analyst                                Mexico
# 6960      Data Analyst  Data Analyst         Monterrey, Nuevo Leon, Mexico
# 8778      Data Analyst  Data Analyst          Guadalajara, Jalisco, Mexico
# 9898      Data Analyst  Data Analyst             Mexico City, CDMX, Mexico
# ...                ...           ...                                   ...
# 782889    Data Analyst  Data Analyst                                Mexico
# 782907    Data Analyst  Data Analyst                                Mexico
# 784639    Data Analyst  Data Analyst             Mexico City, CDMX, Mexico
# 784736    Data Analyst  Data Analyst  Jalisco del Refugio, Jalisco, Mexico
# 784878    Data Analyst  Data Analyst             Mexico City, CDMX, Mexico
#
# ...

# %%
df_unique.drop_duplicates(subset=["job_title", "job_country"])      # returns the remaining rows and columns - 297365 rows × 17 columns
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785729         Data Engineer
# 785734      Business Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785729               Data Engineer Marketing Intelligence
# 785734                                  PreSales Engineer
# 785738                     Commercial Analyst - Start Now
# ...

# %%
len_df_unique = len(df_unique)


print(f"Number of rows in original dataFrame: {len_df_unique}")
df_unique.drop_duplicates(subset=["job_title", "job_country"], inplace = True)
print(f"Number of rows after droping the duplicates: {len(df_unique)}")
print(f"Number of rows Delected: {len_df_unique - len(df_unique)}")
# Out:
# Number of rows in original dataFrame: 785640
# Number of rows after droping the duplicates: 297365
# Number of rows Delected: 488275

# %%
df_unique.shape
# Out:
# (297365, 17)

# %%
df.sample(n=100, random_state=42)           # Now we can see how diverse the dataset is...
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# ...                       ...
# 679274         Data Scientist
# 618989           Data Analyst
# 317705      Software Engineer
# 643190           Data Analyst
# 300299           Data Analyst
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# ...                                                   ...
# 679274  Generative AI Project Manager - Data Science &...
# 618989                             Data Analyst - Finance
# 317705                                    Cloud Developer
# ...
