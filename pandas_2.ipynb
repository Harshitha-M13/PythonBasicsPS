# %%
import pandas as pd

# %%
from datasets import load_dataset


df = load_dataset("lukebarousse/data_jobs")["train"].to_pandas()

# %%
df.head()
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                                NaN
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %%
df.head(10)
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                                NaN
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5         Data Engineer  ...  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  Senior Data Engineer  ...  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7         Data Engineer  ...  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8      Business Analyst  ...  {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9        Data Scientist  ...  {'analyst_tools': ['excel'], 'cloud': ['azure'...
#
# [10 rows x 17 columns]

# %%
df[["job_title_short", "job_title"]].head()
# Out:
#         job_title_short                                          job_title
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs

# %%
df.tail()
# Out:
#           job_title_short  ...                                    job_type_skills
# 785736  Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737       Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738   Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739      Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740  Software Engineer  ...              {'cloud': ['aws'], 'other': ['flow']}
#
# [5 rows x 17 columns]

# %%
df.tail(10)
# Out:
#              job_title_short  ...                                    job_type_skills
# 785731         Data Engineer  ...  {'analyst_tools': ['excel'], 'cloud': ['aws', ...
# 785732         Data Engineer  ...  {'cloud': ['azure', 'databricks'], 'databases'...
# 785733     Software Engineer  ...                {'other': ['docker', 'kubernetes']}
# 785734      Business Analyst  ...                                {'os': ['windows']}
# 785735  Senior Data Engineer  ...  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740     Software Engineer  ...              {'cloud': ['aws'], 'other': ['flow']}
#
# [10 rows x 17 columns]

# %%
df[["job_title_short", "job_title"]].tail()
# Out:
#           job_title_short                                          job_title
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst

# %%
df["job_title_short"] == "Data Analyst"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
df[df["job_title_short"] == "Data Analyst"]
# Out:
#        job_title_short  ...                                    job_type_skills
# 1         Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12        Data Analyst  ...  {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18        Data Analyst  ...  {'analyst_tools': ['excel', 'looker', 'tableau...
# 31        Data Analyst  ...                           {'programming': ['sql']}
# 34        Data Analyst  ...                         {'analyst_tools': ['sap']}
# ...                ...  ...                                                ...
# 785703    Data Analyst  ...                                                NaN
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 785715    Data Analyst  ...                                                NaN
# 785717    Data Analyst  ...                        {'cloud': ['aws', 'azure']}
# 785737    Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# ...

# %%
df[df["job_title_short"] == "Data Analyst"].count()
# Out:
# job_title_short          196075
# job_title                196075
# job_location             195801
# job_via                  196067
# job_schedule_type        191475
# job_work_from_home       196075
# search_location          196075
# job_posted_date          196075
# job_no_degree_mention    196075
# job_health_insurance     196075
# job_country              196067
# salary_rate                9746
# salary_year_avg            5451
# salary_hour_avg            4138
# company_name             196070
# job_skills               159394
# job_type_skills          159394
# dtype: int64

# %%
df[df["job_title_short"] == "Data Analyst" and df["salary_year_avg"] > 1_00_000]            # Python's normal and expects one single True/False value, so we used "&" - bitwise operator
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[df["job_title_short"] == "Data Analyst" and df["salary_year_avg"] > 1_00_000]            # Python's normal and expects one single True/False value, so we used "&" - bitwise operator
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:1513, in NDFrame.__bool__(self)
#    1511     @final
#    1512     def __bool__(self) -> NoReturn:
# -> 1513         raise ValueError(
#    1514             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1516         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df["job_title_short"] == "Data Analyst" & df["salary_year_avg"] > 1_00_000]          # operator precedence, it starts trying to evaluate the expression involving & before the comparisons are completed.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/ops/array_ops.py:374, in na_logical_op(x, y, op)
#     365 try:
#     366     # For exposition, write:
#     367     #  yarr = isinstance(y, np.ndarray)
#    (...)    372     # Then Cases where this goes through without raising include:
#     373     #  (xint or xbool) and (yint or bool)
# --> 374     result = op(x, y)
#     375 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/roperator.py:55, in rand_(left, right)
#      54 def rand_(left, right):
# ---> 55     return operator.and_(right, left)
#
# ...

# %%
df[(df["job_title_short"] == "Data Analyst") & (df["salary_year_avg"] > 100000)]
# Out:
#        job_title_short  ...                                    job_type_skills
# 410       Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 1555      Data Analyst  ...  {'cloud': ['databricks'], 'libraries': ['spark']}
# 1681      Data Analyst  ...  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 1684      Data Analyst  ...  {'cloud': ['azure', 'databricks'], 'os': ['lin...
# 1867      Data Analyst  ...  {'programming': ['php', 'python'], 'webframewo...
# ...                ...  ...                                                ...
# 783588    Data Analyst  ...  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 783866    Data Analyst  ...                                   {'os': ['unix']}
# 784033    Data Analyst  ...         {'analyst_tools': ['power bi', 'tableau']}
# 785187    Data Analyst  ...  {'analyst_tools': ['looker'], 'programming': [...
# 785515    Data Analyst  ...                                                NaN
#
# ...

# %%
df[(df["job_title_short"] == "Data Analyst") & (df["salary_year_avg"] > 100000)].head()
# Out:
#      job_title_short  ...                                    job_type_skills
# 410     Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 1555    Data Analyst  ...  {'cloud': ['databricks'], 'libraries': ['spark']}
# 1681    Data Analyst  ...  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 1684    Data Analyst  ...  {'cloud': ['azure', 'databricks'], 'os': ['lin...
# 1867    Data Analyst  ...  {'programming': ['php', 'python'], 'webframewo...
#
# [5 rows x 17 columns]

# %%
True & True
# Out:
# True

# %%
df[(df["job_title_short"] == "Data Analyst") & df["salary_year_avg"].notna()]
# Out:
#        job_title_short  ...                                    job_type_skills
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 180       Data Analyst  ...         {'analyst_tools': ['excel', 'powerpoint']}
# 410       Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 988       Data Analyst  ...  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 1413      Data Analyst  ...  {'analyst_tools': ['excel', 'power bi'], 'prog...
# ...                ...  ...                                                ...
# 784033    Data Analyst  ...         {'analyst_tools': ['power bi', 'tableau']}
# 784423    Data Analyst  ...         {'analyst_tools': ['tableau', 'power bi']}
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 785187    Data Analyst  ...  {'analyst_tools': ['looker'], 'programming': [...
# 785515    Data Analyst  ...                                                NaN
#
# ...

# %%
df[(df["job_title_short"] == "Data Analyst") & df["salary_year_avg"].notna()].count()
# Out:
# job_title_short          5451
# job_title                5451
# job_location             5372
# job_via                  5451
# job_schedule_type        5443
# job_work_from_home       5451
# search_location          5451
# job_posted_date          5451
# job_no_degree_mention    5451
# job_health_insurance     5451
# job_country              5451
# salary_rate              5451
# salary_year_avg          5451
# salary_hour_avg             0
# company_name             5451
# job_skills               4845
# job_type_skills          4845
# dtype: int64

# %%
df[(df["job_title_short"] == "Data Analyst") & df["salary_year_avg"].notna()].head()
# Out:
#      job_title_short  ...                                    job_type_skills
# 109     Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 180     Data Analyst  ...         {'analyst_tools': ['excel', 'powerpoint']}
# 410     Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 988     Data Analyst  ...  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 1413    Data Analyst  ...  {'analyst_tools': ['excel', 'power bi'], 'prog...
#
# [5 rows x 17 columns]

# %%
df[(df["job_title_short"] == "Data Analyst") & df["salary_year_avg"].notna()].tail()
# Out:
#        job_title_short  ...                                    job_type_skills
# 784033    Data Analyst  ...         {'analyst_tools': ['power bi', 'tableau']}
# 784423    Data Analyst  ...         {'analyst_tools': ['tableau', 'power bi']}
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 785187    Data Analyst  ...  {'analyst_tools': ['looker'], 'programming': [...
# 785515    Data Analyst  ...                                                NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# # df.info()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  str
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
# or

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='str')

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
len(df)
# Out:
# 785741

# %%
df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %% [markdown]
# # df.describe()

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %% [markdown]
# # df.iloc[start_index, end_index]   - int location

# %%
df.iloc[0:5]
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                                NaN
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %%
df.iloc[1:6:2]
# Out:
#   job_title_short  ...                                    job_type_skills
# 1    Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 3   Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5   Data Engineer  ...  {'cloud': ['gcp'], 'programming': ['python', '...
#
# [3 rows x 17 columns]

# %%
df.iloc[90:101]
# Out:
#           job_title_short  ...                                    job_type_skills
# 90         Data Scientist  ...  {'analyst_tools': ['tableau'], 'libraries': ['...
# 91         Data Scientist  ...  {'analyst_tools': ['excel', 'tableau'], 'libra...
# 92          Data Engineer  ...                 {'programming': ['sql', 'python']}
# 93           Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# 94          Data Engineer  ...  {'analyst_tools': ['power bi', 'tableau'], 'cl...
# 95          Data Engineer  ...  {'analyst_tools': ['tableau'], 'databases': ['...
# 96          Data Engineer  ...  {'analyst_tools': ['sap'], 'cloud': ['azure', ...
# 97           Data Analyst  ...                                                NaN
# 98   Senior Data Engineer  ...  {'cloud': ['aws', 'databricks'], 'libraries': ...
# 99          Data Engineer  ...  {'libraries': ['react', 'spark', 'hadoop'], 'o...
# ...

# %%
df["job_title_short"].iloc[1:6]
# Out:
# 1     Data Analyst
# 2    Data Engineer
# 3    Data Engineer
# 4    Data Engineer
# 5    Data Engineer
# Name: job_title_short, dtype: str

# %%
df[["job_title_short"]].loc[1:6]
# Out:
#         job_title_short
# 1          Data Analyst
# 2         Data Engineer
# 3         Data Engineer
# 4         Data Engineer
# 5         Data Engineer
# 6  Senior Data Engineer

# %%
df[["job_title_short", "job_title"]]
# Out:
#              job_title_short                                          job_title
# 0       Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1               Data Analyst                                       Data Analyst
# 2              Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3              Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4              Data Engineer                             Data Engineer- Sr Jobs
# ...                      ...                                                ...
# 785736     Software Engineer                                    DevOps Engineer
# 785737          Data Analyst                                   CRM Data Analyst
# 785738      Business Analyst                     Commercial Analyst - Start Now
# 785739         Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740     Software Engineer                                 AWS System Analyst
#
# ...

# %%
df[["job_title_short", "job_title"]].loc[1:6]
# Out:
#         job_title_short                                          job_title
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud

# %% [markdown]
# # .unique()

# %%
df["job_title_short"].unique()
# Out:
# <ArrowStringArray>
# [     'Senior Data Engineer',              'Data Analyst',
#              'Data Engineer',          'Business Analyst',
#             'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst',            'Cloud Engineer',
#      'Senior Data Scientist',         'Software Engineer']
# Length: 10, dtype: str

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.unique()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  str
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
type(df["job_posted_date"])
# Out:
# pandas.Series

# %%
type(df["job_posted_date"][0])
# Out:
# str

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
type(df["job_posted_date"])
# Out:
# pandas.Series

# %%
type(df["job_posted_date"][0])
# Out:
# pandas.Timestamp

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
# or

df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
# or

df.job_posted_date = pd.to_datetime(df["job_posted_date"])

# %%
df["job_posted_date"].dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df[["job_posted_date"]].dt.month        # returns a DataFrame, not a Series. And .dt is an accessor for a datetime Series, not for the whole DataFrame.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df[["job_posted_date"]].dt.month        # returns a DataFrame, not a Series. And .dt is an accessor for a datetime Series, not for the whole DataFrame.
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dt'

# %%
df["job_posted_month"] = df["job_posted_date"].dt.month

# %%
df.head()
# Out:
#         job_title_short  ... job_posted_month
# 0  Senior Data Engineer  ...                6
# 1          Data Analyst  ...                1
# 2         Data Engineer  ...               10
# 3         Data Engineer  ...                7
# 4         Data Engineer  ...                8
#
# [5 rows x 18 columns]

# %%
df["job_posted_month"]
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int32

# %%
df[["job_posted_month"]]
# Out:
#         job_posted_month
# 0                      6
# 1                      1
# 2                     10
# 3                      7
# 4                      8
# ...                  ...
# 785736                 3
# 785737                 3
# 785738                 3
# 785739                 3
# 785740                 3
#
# [785741 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
df.sort_values(df["job_posted_date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df.sort_values(df["job_posted_date"])
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
# ...

# %%
help(df.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(
#     by: IndexLabel,
#     *,
#     axis: Axis = 0,
#     ascending: bool | list[bool] | tuple[bool, ...] = True,
#     inplace: bool = False,
#     kind: SortKind = 'quicksort',
#     na_position: str = 'last',
#     ignore_index: bool = False,
#     key: ValueKeyFunc | None = None
# ) -> DataFrame | None method of pandas.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names to sort by.
#
#         - if `axis` is 0 or `'index'` then `by` may contain index
#           levels and/or column labels.
#         - if `axis` is 1 or `'columns'` then `by` may contain column
#           levels and/or index labels.
#     axis : "{0 or 'index', 1 or 'columns'}", default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
# ...

# %%
df.sort_values("job_posted_date")
# Out:
#                   job_title_short  ... job_posted_month
# 108804               Data Analyst  ...                1
# 96906                Data Analyst  ...                1
# 98438                Data Analyst  ...                1
# 110290               Data Analyst  ...                1
# 72158         Senior Data Analyst  ...                1
# ...                           ...  ...              ...
# 362129              Data Engineer  ...               12
# 351830              Data Engineer  ...               12
# 327439              Data Engineer  ...               12
# 112373        Senior Data Analyst  ...               12
# 90102   Machine Learning Engineer  ...               12
#
# [785741 rows x 18 columns]

# %%
df
# Out:
#              job_title_short  ... job_posted_month
# 0       Senior Data Engineer  ...                6
# 1               Data Analyst  ...                1
# 2              Data Engineer  ...               10
# 3              Data Engineer  ...                7
# 4              Data Engineer  ...                8
# ...                      ...  ...              ...
# 785736     Software Engineer  ...                3
# 785737          Data Analyst  ...                3
# 785738      Business Analyst  ...                3
# 785739         Data Engineer  ...                3
# 785740     Software Engineer  ...                3
#
# [785741 rows x 18 columns]

# %%
df = df.sort_values("job_posted_date")

# or

df.sort_values("job_posted_date", ascending = True, inplace = True)

# or

df.sort_values(by=["job_posted_date", "job_posted_month"], inplace = True)        # Best Practice

# %%
df
# Out:
#                   job_title_short  ... job_posted_month
# 108804               Data Analyst  ...                1
# 96906                Data Analyst  ...                1
# 98438                Data Analyst  ...                1
# 110290               Data Analyst  ...                1
# 72158         Senior Data Analyst  ...                1
# ...                           ...  ...              ...
# 362129              Data Engineer  ...               12
# 351830              Data Engineer  ...               12
# 327439              Data Engineer  ...               12
# 112373        Senior Data Analyst  ...               12
# 90102   Machine Learning Engineer  ...               12
#
# [785741 rows x 18 columns]

# %%
# For columns .drop(column_name)

df.drop(labels="job_posted_month", axis=1)     # Best Practice    # axis = 1 (for columns) and axis = 0 for rows


# or


df.drop("job_posted_month", axis=1)
# Out:
#                   job_title_short  ...                                    job_type_skills
# 108804               Data Analyst  ...  {'analyst_tools': ['visio'], 'async': ['jira',...
# 96906                Data Analyst  ...  {'analyst_tools': ['sas'], 'programming': ['sq...
# 98438                Data Analyst  ...  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 110290               Data Analyst  ...        {'async': ['jira'], 'programming': ['sql']}
# 72158         Senior Data Analyst  ...  {'async': ['jira'], 'other': ['atlassian'], 'p...
# ...                           ...  ...                                                ...
# 351830              Data Engineer  ...  {'analyst_tools': ['power bi', 'word'], 'cloud...
# 362129              Data Engineer  ...  {'cloud': ['snowflake'], 'libraries': ['airflo...
# 327439              Data Engineer  ...  {'other': ['kubernetes'], 'webframeworks': ['e...
# ...

# %%
df
# Out:
#                   job_title_short  ... job_posted_month
# 108804               Data Analyst  ...                1
# 96906                Data Analyst  ...                1
# 98438                Data Analyst  ...                1
# 110290               Data Analyst  ...                1
# 72158         Senior Data Analyst  ...                1
# ...                           ...  ...              ...
# 351830              Data Engineer  ...               12
# 362129              Data Engineer  ...               12
# 327439              Data Engineer  ...               12
# 112373        Senior Data Analyst  ...               12
# 90102   Machine Learning Engineer  ...               12
#
# [785741 rows x 18 columns]

# %%
df.drop("job_posted_month", axis=1, inplace=True)

# %%
df
# Out:
#                   job_title_short  ...                                    job_type_skills
# 108804               Data Analyst  ...  {'analyst_tools': ['visio'], 'async': ['jira',...
# 96906                Data Analyst  ...  {'analyst_tools': ['sas'], 'programming': ['sq...
# 98438                Data Analyst  ...  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 110290               Data Analyst  ...        {'async': ['jira'], 'programming': ['sql']}
# 72158         Senior Data Analyst  ...  {'async': ['jira'], 'other': ['atlassian'], 'p...
# ...                           ...  ...                                                ...
# 351830              Data Engineer  ...  {'analyst_tools': ['power bi', 'word'], 'cloud...
# 362129              Data Engineer  ...  {'cloud': ['snowflake'], 'libraries': ['airflo...
# 327439              Data Engineer  ...  {'other': ['kubernetes'], 'webframeworks': ['e...
# ...

# %%
# or rows .drop(index)

df.drop(108804, axis=0)
# Out:
#                   job_title_short  ...                                    job_type_skills
# 96906                Data Analyst  ...  {'analyst_tools': ['sas'], 'programming': ['sq...
# 98438                Data Analyst  ...  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 110290               Data Analyst  ...        {'async': ['jira'], 'programming': ['sql']}
# 72158         Senior Data Analyst  ...  {'async': ['jira'], 'other': ['atlassian'], 'p...
# 104526               Data Analyst  ...                       {'analyst_tools': ['excel']}
# ...                           ...  ...                                                ...
# 351830              Data Engineer  ...  {'analyst_tools': ['power bi', 'word'], 'cloud...
# 362129              Data Engineer  ...  {'cloud': ['snowflake'], 'libraries': ['airflo...
# 327439              Data Engineer  ...  {'other': ['kubernetes'], 'webframeworks': ['e...
# ...

# %%
# More easy

df.drop(columns="job_posted_month")
# Out:
#                   job_title_short  ...                                    job_type_skills
# 108804               Data Analyst  ...  {'analyst_tools': ['visio'], 'async': ['jira',...
# 96906                Data Analyst  ...  {'analyst_tools': ['sas'], 'programming': ['sq...
# 98438                Data Analyst  ...  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 110290               Data Analyst  ...        {'async': ['jira'], 'programming': ['sql']}
# 72158         Senior Data Analyst  ...  {'async': ['jira'], 'other': ['atlassian'], 'p...
# ...                           ...  ...                                                ...
# 351830              Data Engineer  ...  {'analyst_tools': ['power bi', 'word'], 'cloud...
# 362129              Data Engineer  ...  {'cloud': ['snowflake'], 'libraries': ['airflo...
# 327439              Data Engineer  ...  {'other': ['kubernetes'], 'webframeworks': ['e...
# ...

# %%
# If we want to drop the list of columns

df.drop(columns=["job_title_short", "job_title"])
# Out:
#                   job_location  ... job_posted_month
# 108804            New York, NY  ...                1
# 96906           Bloomfield, CT  ...                1
# 98438           Washington, DC  ...                1
# 110290             Fairfax, VA  ...                1
# 72158            Worcester, MA  ...                1
# ...                        ...  ...              ...
# 351830       San Francisco, CA  ...               12
# 362129           Sunnyvale, CA  ...               12
# 327439          Southfield, MI  ...               12
# 112373  Boston, MA  (+1 other)  ...               12
# 90102               Boston, MA  ...               12
#
# [785741 rows x 16 columns]

# %%
df.dropna(subset="job_title_short")
# Out:
#                   job_title_short  ... job_posted_month
# 108804               Data Analyst  ...                1
# 96906                Data Analyst  ...                1
# 98438                Data Analyst  ...                1
# 110290               Data Analyst  ...                1
# 72158         Senior Data Analyst  ...                1
# ...                           ...  ...              ...
# 362129              Data Engineer  ...               12
# 351830              Data Engineer  ...               12
# 327439              Data Engineer  ...               12
# 112373        Senior Data Analyst  ...               12
# 90102   Machine Learning Engineer  ...               12
#
# [785741 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  str
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
df[df["salary_rate"].isnull()]
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                                NaN
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
df.dropna(subset="salary_rate", inplace=True)

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 28            Data Scientist  ...  {'analyst_tools': ['excel'], 'libraries': ['gd...
# 43      Senior Data Engineer  ...  {'databases': ['sql server'], 'programming': [...
# 51      Senior Data Engineer  ...  {'cloud': ['aws', 'databricks'], 'libraries': ...
# 77             Data Engineer  ...  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92             Data Engineer  ...                 {'programming': ['sql', 'python']}
# ...                      ...  ...                                                ...
# 785624         Data Engineer  ...  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641         Data Engineer  ...                                                NaN
# 785648        Data Scientist  ...  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682        Data Scientist  ...  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# ...

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 df.median()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:14594, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   14590         >>> df.median(numeric_only=True)
#   14591         a   1.5
#   14592         dtype: float64
#   14593         """
# ...

# %%
df["salary_year_avg"].median()
# Out:
# np.float64(115000.0)

# %%
df["salary_hour_avg"].min()
# Out:
# np.float64(8.0)

# %%
# index of min

df["salary_hour_avg"].idxmin()
# Out:
# np.int64(88185)

# %%
df[88185]       # Find the column named 88185.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 88185
#
# ...

# %%
df["salary_hour_avg"][88185]
# Out:
# np.float64(8.0)

# %%
df.iloc[88185:88186]
# Out:
#       job_title_short  ...                                    job_type_skills
# 88185  Data Scientist  ...  {'analyst_tools': ['word', 'tableau'], 'cloud'...
#
# [1 rows x 17 columns]

# %%
min_salary = df["salary_year_avg"].min()


min_salary
# Out:
# np.float64(15000.0)

# %%
idx_min_salary = df["salary_year_avg"].idxmin()

idx_min_salary
# Out:
# 665729

# %%
df.iloc[idx_min_salary: idx_min_salary + 1]
# Out:
#        job_title_short  ...                                    job_type_skills
# 665729   Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'libraries': ['ha...
#
# [1 rows x 17 columns]

# %%
df.iloc[idx_min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df["job_title_short"].unique()
# Out:
# <ArrowStringArray>
# [     'Senior Data Engineer',              'Data Analyst',
#              'Data Engineer',          'Business Analyst',
#             'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst',            'Cloud Engineer',
#      'Senior Data Scientist',         'Software Engineer']
# Length: 10, dtype: str

# %%
df["job_title_short"].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64
